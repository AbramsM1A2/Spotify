# %%
import json
#USER_DIR = 'C:/Users/abram/Documents/MATI/Spotify/api'
USER_DIR = 'C:/Users/abram/Documents/MATI/Spotify/api'

# %%
jPlay1 = os.path.join(USER_DIR,'50cent-dataPlaylist22.json')
jPlay2 = os.path.join(USER_DIR,'50cent-dataPlaylist34.json')
jPlay3 = os.path.join(USER_DIR,'50cent-dataPlaylist36.json')
jPlay4 = os.path.join(USER_DIR,'50cent-dataPlaylist41.json')
dataPlay1 = json.loads(open(jPlay1).read())
dataPlay2 = json.loads(open(jPlay2).read())
dataPlay3 = json.loads(open(jPlay3).read())
dataPlay4 = json.loads(open(jPlay4).read())
dataPlayLists = [dataPlay1, dataPlay2, dataPlay3, dataPlay4]

# %%
G=Graph()
b = len(dataPlayLists)
artistas = []
for i in range(0,b):
    a = dataPlayLists[i]
    z = len(a)
    for j in range(0, z):
        c = a[j]
        
        artistas.append(c['2'])
        #G.add_edge(c['2'])
        

res = []
[res.append(x) for x in artistas if x not in res]

print(res)
# Out:
# [['G-Unit', 'Young Buck'], ['50 Cent'], ['LL Cool J'], ['Snoop Dogg', 'Daz Dillinger'], ['50 Cent', 'Trey Songz'], ['Mobb Deep'], ['Mase', 'The LOX', 'Black Rob', 'DMX'], ['Eric B. & Rakim'], ['Nas'], ['Kidd Kidd'], ['New Edition'], ['JAY-Z'], ['The LOX'], ['Wu-Tang Clan'], ['Eminem'], ['2Pac', 'Dramacydal'], ['The Notorious B.I.G.'], ['Dr. Dre', 'Snoop Dogg'], ['Kendrick Lamar'], ['Michael Jackson'], ['Jeremih', '50 Cent'], ['Trey Songz', 'Nicki Minaj'], ['50 Cent', 'Eminem'], ['50 Cent', 'Nate Dogg'], ['50 Cent', 'Olivia'], ['50 Cent', 'Mobb Deep'], ['50 Cent', 'The Game', 'Tony Yayo', 'Young Buck', 'Lloyd Banks'], ['50 Cent', 'Young Buck'], ['Eminem', '50 Cent', 'Ca$his', 'Lloyd Banks'], ['50 Cent', 'Justin Timberlake', 'Timbaland'], ['50 Cent', 'Akon'], ['50 Cent', 'Ne-Yo'], ['50 Cent', 'Dr. Dre', 'Alicia Keys'], ['50 Cent', 'Eminem', 'Adam Levine'], ['50 Cent', 'Yo Gotti'], ['50 Cent', 'Jadakiss', 'Kidd Kidd'], ['50 Cent', 'The Madd Rapper'], ['The Game', '50 Cent'], ['2Pac', '50 Cent'], ["Lil' Kim"], ['Snoop Dogg', '50 Cent'], ['Young Buck'], ['Eminem', 'Dr. Dre', '50 Cent'], ['Tony Yayo', '50 Cent'], ['Mobb Deep', '50 Cent', 'Nate Dogg'], ['M.O.P.', '50 Cent', 'Young Buck'], ['LoveRance', '50 Cent'], ['Nicole Scherzinger', '50 Cent'], ['Eminem', '50 Cent'], ['Justin Timberlake', '50 Cent'], ['Timbaland', '50 Cent', 'Tony Yayo'], ['Soulja Boy', '50 Cent'], ['Onyx'], ['Eminem', '50 Cent', 'Nate Dogg'], ['Mary J. Blige', '50 Cent'], ['Lloyd Banks', '50 Cent'], ['DMX', '50 Cent', 'Styles P'], ['Michael Jackson', '50 Cent'], ['Freeway', '50 Cent'], ['Ciara', '50 Cent'], ['Missy Elliott', '50 Cent'], ['LL Cool J', '50 Cent'], ['Pusha T', '50 Cent', 'Pharrell Williams'], ['50 Cent', 'Jeremih', 'T.I.', '2 Chainz'], ['50 Cent', 'Too $hort'], ['50 Cent', 'Snoop Dogg', 'Jeezy'], ['50 Cent', 'Kendrick Lamar'], ['50 Cent', 'Joe'], ['50 Cent', 'Mr. Probz']]

# %%
G.show(figsize=15)
print(G)
# Out:
# Graphics object consisting of 314 graphics primitives
# Graph on 176 vertices
